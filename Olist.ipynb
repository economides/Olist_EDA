# %%
import pandas as pd
import os
from os import listdir
from os.path import isfile, join

# %matplotlib inline
import matplotlib.pyplot as plt


os.chdir("C:\\Users\\Dimitris\\Desktop\\Data Science Training\\Olist\\Data")

mypath = os.getcwd()

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

print(onlyfiles)
# Out:
# ['brazilian-ecommerce.zip', 'olist_closed_deals_dataset.csv', 'olist_marketing_qualified_leads_dataset.csv', 'Untitled.ipynb', 'Widgets.ipynb']

# %%
mql = pd.read_csv("olist_marketing_qualified_leads_dataset.csv")
cd = pd.read_csv("olist_closed_deals_dataset.csv")

print(mql.shape)
print(cd.shape)
# Out:
# (8000, 4)
# (842, 14)

# %%
mql.head()
# Out:
#                              mql_id first_contact_date  \
# 0  dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1  8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2  b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3  6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4  5420aad7fec3549a85876ba1c529bd84         2018-02-21
#
#                     landing_page_id          origin
# 0  88740e65d5d6b056e0cda098e1ea6313          social
# 1  007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2  a7982125ff7aa3b2054c6e44f9d28522  organic_search
# 3  d45d558f0daeecf3cccdffe3c59684aa           email
# 4  b48ec5f3b04e9068441002a19df93c6c  organic_search

# %%
df = mql.merge(cd,
               on="mql_id",
               how="left")
df.head(8)
# Out:
#                              mql_id first_contact_date  \
# 0  dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1  8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2  b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3  6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4  5420aad7fec3549a85876ba1c529bd84         2018-02-21
# 5  28bdfd5f057764b54c38770f95c69f2f         2018-01-14
# 6  126a0d10becbaafcb2e72ce6848cf32c         2018-05-15
# 7  f76136f54d14a3345951f25b7932366b         2018-05-24
#
#                     landing_page_id          origin  \
# 0  88740e65d5d6b056e0cda098e1ea6313          social
# 1  007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2  a7982125ff7aa3b2054c6e44f9d28522  organic_search
# 3  d45d558f0daeecf3cccdffe3c59684aa           email
# 4  b48ec5f3b04e9068441002a19df93c6c  organic_search
# 5  22c29808c4f815213303f8933030604c  organic_search
# 6  6a110e795dd487f1cf8d7583671987af           email
# ...

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://i.imgur.com/Jory0O3.png")
# Out:
# <img src="https://i.imgur.com/Jory0O3.png"/>

# %%
cd2 = cd.groupby('business_type').sum().

# %%
# cd2.style.bar(subset=['declared_product_catalog_size',
#                       'declared_monthly_revenue'],
#               color='#d65f5f')

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://i.imgur.com/HRhd2Y0.png")
# Out:
# <img src="https://i.imgur.com/HRhd2Y0.png"/>
